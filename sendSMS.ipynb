# %% [markdown]
# **SEND MESSAGE THROUGH WHATSAPP**

# %% [markdown]
# **Send SMS with Twilio**

# %%
# !pip3 install twilio

# %%
from twilio.rest import Client

# %%
account_sid = 'AC4b2296dc98cf9b4a93cd3a0e097a460f'
auth_token = '4331d6dc31d535134979bb8bde009cec'

# %%
client = Client(account_sid , auth_token)

# %%
msg = client.messages.create(
    to ='+919061878989',
    from_='+1 442 264 0884',
    body = 'Hey..............good morningggg?'

)
print(msg.sid)
print("message sent succesfully")
# Out:
# SMd2ec333e3fab4753a8198dfe2670ac0d
# message sent succesfully
