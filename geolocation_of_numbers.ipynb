# %%
# !pip install phonenumbers

# %%
my_number = "+918089807474"

# %% [markdown]
# **geoLocation**

# %%
import phonenumbers
from phonenumbers import geocoder

ch_number = phonenumbers.parse(my_number , 'CH')
print(geocoder.description_for_number(ch_number, 'en'))
# Out:
# India

# %% [markdown]
# **ServiceProvider**

# %%
from phonenumbers import carrier

service_number = phonenumbers.parse(my_number , 'RO',)
print(carrier.name_for_number(service_number , 'en'))
# Out:
# Tata Docomo

# %% [markdown]
# **Track location using IP address**

# %%
# !pip install pygeoip

# %%
from google.colab import drive,files
drive.mount('/content/MyDrive/')
# Out:
# Mounted at /content/MyDrive/

# %%
# %cd /content/MyDrive/MyDrive/
# Out:
# /content/MyDrive/MyDrive

# %%
import pygeoip


gip = pygeoip.GeoIP("GeoLiteCity.dat")
res= gip.record_by_addr ('49.15.131.243')

for key, val in res.items():
  print('%s : %s' % (key,val))
# Out:
# dma_code : 0
# area_code : 0
# metro_code : None
# postal_code : 682001
# country_code : IN
# country_code3 : IND
# country_name : India
# continent : AS
# region_code : 13
# city : Kochi
# latitude : 9.966700000000003
# longitude : 76.23329999999999
# time_zone : Asia/Calcutta
